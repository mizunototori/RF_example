# %%
from RandomForest_irradianceEstimation import RandomForest_irradianceEstimation
# %matplotlib inline

# %%
point_name = 'Sapporo'
stlfile = 'data/April/'+point_name+'/'
grmfile = 'data/April/'+point_name+'/'
load_files=[grmfile+'ts_H.txt',grmfile+'ts_extH.txt',\
            stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt',\
            stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 5000
end_idx = -1
days  = [29, 15, 19, 24];
test_idx = [[15796,16367],[7732,8306],[10036,10610],[12916,13490]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, days, test_idx, N_est=10,from_idx=from_idx)

# %%
point_name = 'Nara'
stlfile = 'data/April/'+point_name+'/'
grmfile = 'data/April/'+point_name+'/'
load_files=[grmfile+'ts_H.txt',grmfile+'ts_extH.txt',stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt', stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 4000
end_idx = -5000
days  = [18, 10, 9, 11];
test_idx = [[9460,10034], [4852,5426], [4276,4850],[5428,6002]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, days, test_idx, N_est=30,from_idx=from_idx)

# %%
point_name = 'Tokyo'
stlfile = 'data/April/'+point_name+'/'
grmfile = 'data/April/'+point_name+'/'
load_files=[grmfile+'ts_H.txt',grmfile+'ts_extH.txt',stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt', stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 40
end_idx = -300
days  = [23, 10, 15, 11];
test_idx=[[12340,12914], [4852,5426], [7732,8306], [5428,6002]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, days, test_idx, from_idx=from_idx, end_idx=end_idx)

# %%
point_name = 'Kumamoto'
stlfile = 'data/April/'+point_name+'/'
grmfile = 'data/April/'+point_name+'/'
load_files=[grmfile+'ts_H.txt',grmfile+'ts_extH.txt',\
            stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt',\
            stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 40
end_idx = -1
days  = [17, 10, 14, 6];
test_idx=[[8884,9458],[4852,5426],[7156,7730],[2548,3122]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, days, test_idx, from_idx=from_idx, end_idx=end_idx)

# %%
point_name = 'Naha'
stlfile = 'data/April/'+point_name+'/'
grmfile = 'data/April/'+point_name+'/'
load_files=[grmfile+'ts_H.txt',grmfile+'ts_extH.txt',\
            stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt', \
            stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 40
end_idx = -1
days  = [29, 15, 19, 24];
test_idx = [[15796,16367],[7732,8306],[10036,10610],[12916,13490]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, from_idx, days, test_idx)

# %%
point_name = 'FREA'
stlfile = 'data/April/'+point_name+'/satellite/'
grmfile = 'data/April/'+point_name+'/ground_measure/'
load_files=[grmfile+'ts_FREA_H.txt',grmfile+'ts_FREA_extH.txt', \
            stlfile+'ts_rhop_B01.txt', stlfile+'ts_rhop_B02.txt',stlfile+'ts_rhop_B03.txt', \
            stlfile+'ts_rhop_B04.txt',stlfile+'ts_rhop_B05.txt', stlfile+'ts_rhop_B06.txt']#, stlfile+'ts_rhop_B07.txt', stlfile+'ts_rhop_B08.txt', stlfile+'ts_rhop_B09.txt', stlfile+'ts_rhop_B10.txt',stlfile+'ts_rhop_B12.txt',stlfile+'ts_rhop_B13.txt',stlfile+'ts_rhop_B14.txt',stlfile+'ts_rhop_B15.txt',stlfile+'ts_rhop_B16.txt']
from_idx = 40
end_idx = -1
FREA_days  = [26, 4, 29, 14];
test_idx = [[36894,38332],[5222,6660],[41214,42651],[19622,21060]]

# %%
RandomForest_irradianceEstimation(point_name, load_files, from_idx, days, test_idx)
